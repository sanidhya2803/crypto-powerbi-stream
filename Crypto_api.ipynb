# %% [markdown]
# <a href="https://colab.research.google.com/github/sanidhya2803/Crypto_API/blob/main/Crypto_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install requests websocket-client
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.12/dist-packages (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.10.5)

# %%
import requests
import time
from datetime import datetime

power_bi_url = "https://api.powerbi.com/beta/a64aeab6-f01b-462b-aa9c-44546386ff31/datasets/907c2814-76b4-4ff4-ab83-c1e705a483b7/rows?experience=power-bi&key=uGCcCkt6oGfCiI69IpALF9zvPE0oyuIaDQjlhFxhW8RhA2fR0%2FuO6pX6qKDahkF1UGnQkBKewq%2FeuHycv3xZJQ%3D%3D"

def get_price(symbol="BTC-USDT"):
    url = f"https://api.kucoin.com/api/v1/market/orderbook/level1?symbol={symbol}"
    headers = {"User-Agent": "Mozilla/5.0"}
    r = requests.get(url, headers=headers)
    data = r.json()
    return float(data["data"]["price"])

while True:
    try:
        price = get_price("BTC-USDT")
        timestamp = datetime.utcnow().isoformat()

        payload = [{
            "crypto": "BITCOIN",
            "price": price,
            "timestamp": timestamp
        }]

        requests.post(power_bi_url, json=payload)
        print(f"✅ Sent → BITCOIN = {price}")

    except Exception as e:
        print("Error:", e)

    time.sleep(2)   # Update every 2 seconds
# Out:
# /tmp/ipython-input-667619641.py:17: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   timestamp = datetime.utcnow().isoformat()
# ✅ Sent → BITCOIN = 103636.9
# ✅ Sent → BITCOIN = 103646.3
# ✅ Sent → BITCOIN = 103650.5
# ✅ Sent → BITCOIN = 103650.5
# ✅ Sent → BITCOIN = 103641.2
# ✅ Sent → BITCOIN = 103608.2
# ✅ Sent → BITCOIN = 103608.0
# ✅ Sent → BITCOIN = 103597.8
# ✅ Sent → BITCOIN = 103612.1
# ✅ Sent → BITCOIN = 103632.4
# ✅ Sent → BITCOIN = 103658.2
# ✅ Sent → BITCOIN = 103658.3
# ✅ Sent → BITCOIN = 103665.7
# ✅ Sent → BITCOIN = 103665.7
# ✅ Sent → BITCOIN = 103679.6
# ✅ Sent → BITCOIN = 103671.9
# ✅ Sent → BITCOIN = 103671.9
# ✅ Sent → BITCOIN = 103671.9
# ✅ Sent → BITCOIN = 103690.9
# ✅ Sent → BITCOIN = 103690.9
# ✅ Sent → BITCOIN = 103692.5
# ✅ Sent → BITCOIN = 103700.9
# ✅ Sent → BITCOIN = 103731.3
# ✅ Sent → BITCOIN = 103731.3
# ✅ Sent → BITCOIN = 103729.4
# ✅ Sent → BITCOIN = 103729.4
# ✅ Sent → BITCOIN = 103729.4
# ✅ Sent → BITCOIN = 103677.5
# ✅ Sent → BITCOIN = 103661.9
# ✅ Sent → BITCOIN = 103680.3
# ✅ Sent → BITCOIN = 103680.3
# ✅ Sent → BITCOIN = 103673.1
# ✅ Sent → BITCOIN = 103665.3
# ✅ Sent → BITCOIN = 103665.4
# ✅ Sent → BITCOIN = 103665.3
# ✅ Sent → BITCOIN = 103665.3
# ✅ Sent → BITCOIN = 103665.3
# ✅ Sent → BITCOIN = 103638.2
# ✅ Sent → BITCOIN = 103638.2
# ✅ Sent → BITCOIN = 103665.4
# ✅ Sent → BITCOIN = 103669.2
# ✅ Sent → BITCOIN = 103669.2
# ✅ Sent → BITCOIN = 103669.1
# ✅ Sent → BITCOIN = 103663.8
# ✅ Sent → BITCOIN = 103663.8
# ✅ Sent → BITCOIN = 103667.8
# ✅ Sent → BITCOIN = 103691.4
# ✅ Sent → BITCOIN = 103689.7
# ✅ Sent → BITCOIN = 103623.1
# ✅ Sent → BITCOIN = 103622.9
# ✅ Sent → BITCOIN = 103650.6
# ✅ Sent → BITCOIN = 103641.7
# ✅ Sent → BITCOIN = 103620.5
# ✅ Sent → BITCOIN = 103653.1
# ✅ Sent → BITCOIN = 103675.4
# ✅ Sent → BITCOIN = 103689.6
# ✅ Sent → BITCOIN = 103712.1
# ✅ Sent → BITCOIN = 103679.8
# ✅ Sent → BITCOIN = 103684.8
# ✅ Sent → BITCOIN = 103711.0
# ✅ Sent → BITCOIN = 103714.6
# ✅ Sent → BITCOIN = 103714.6
# ✅ Sent → BITCOIN = 103725.3
# ✅ Sent → BITCOIN = 103718.3
# ✅ Sent → BITCOIN = 103712.4
# ✅ Sent → BITCOIN = 103723.8
# ✅ Sent → BITCOIN = 103715.4
# ✅ Sent → BITCOIN = 103714.8
# ✅ Sent → BITCOIN = 103725.9
# ✅ Sent → BITCOIN = 103737.1
# ✅ Sent → BITCOIN = 103739.0
# ✅ Sent → BITCOIN = 103738.9
# ✅ Sent → BITCOIN = 103739.0
# ✅ Sent → BITCOIN = 103738.9
# ✅ Sent → BITCOIN = 103702.7
# ✅ Sent → BITCOIN = 103706.9
# ✅ Sent → BITCOIN = 103691.2
# ✅ Sent → BITCOIN = 103708.0
# ✅ Sent → BITCOIN = 103697.5
# ✅ Sent → BITCOIN = 103688.4
# ✅ Sent → BITCOIN = 103697.5
# ✅ Sent → BITCOIN = 103688.4
# ✅ Sent → BITCOIN = 103688.3
# ✅ Sent → BITCOIN = 103697.4
# ✅ Sent → BITCOIN = 103689.0
# ✅ Sent → BITCOIN = 103677.7
# ✅ Sent → BITCOIN = 103663.1
# ✅ Sent → BITCOIN = 103656.6
# ✅ Sent → BITCOIN = 103665.2
# ✅ Sent → BITCOIN = 103657.4
# ✅ Sent → BITCOIN = 103657.4
# ✅ Sent → BITCOIN = 103620.1
# ✅ Sent → BITCOIN = 103598.5
# ✅ Sent → BITCOIN = 103590.4
# ✅ Sent → BITCOIN = 103556.2
# ✅ Sent → BITCOIN = 103555.5
# ✅ Sent → BITCOIN = 103531.8
# ✅ Sent → BITCOIN = 103526.8
# ✅ Sent → BITCOIN = 103525.0
# ✅ Sent → BITCOIN = 103550.5
# ✅ Sent → BITCOIN = 103550.5
# ✅ Sent → BITCOIN = 103567.3
# ✅ Sent → BITCOIN = 103567.3
# ✅ Sent → BITCOIN = 103598.3
# ✅ Sent → BITCOIN = 103600.0
# ✅ Sent → BITCOIN = 103606.4
# ✅ Sent → BITCOIN = 103615.2
# ✅ Sent → BITCOIN = 103615.1
# ✅ Sent → BITCOIN = 103606.3
# ✅ Sent → BITCOIN = 103592.0
# ✅ Sent → BITCOIN = 103598.2
# ✅ Sent → BITCOIN = 103571.7
# ✅ Sent → BITCOIN = 103568.1
# ✅ Sent → BITCOIN = 103621.1
# ✅ Sent → BITCOIN = 103659.8
# ✅ Sent → BITCOIN = 103659.8
# ✅ Sent → BITCOIN = 103671.9
# ✅ Sent → BITCOIN = 103674.5
# ✅ Sent → BITCOIN = 103635.9
# ✅ Sent → BITCOIN = 103651.6
# ✅ Sent → BITCOIN = 103638.8
# ✅ Sent → BITCOIN = 103648.4
# ✅ Sent → BITCOIN = 103657.0
# ✅ Sent → BITCOIN = 103646.2
# ✅ Sent → BITCOIN = 103646.2
# ✅ Sent → BITCOIN = 103646.2
# ✅ Sent → BITCOIN = 103646.3
# ✅ Sent → BITCOIN = 103646.3
# ✅ Sent → BITCOIN = 103651.3
# ✅ Sent → BITCOIN = 103651.3
# ✅ Sent → BITCOIN = 103624.5
# ✅ Sent → BITCOIN = 103604.3
# ✅ Sent → BITCOIN = 103556.2
# ✅ Sent → BITCOIN = 103626.9
# ✅ Sent → BITCOIN = 103614.6
# ✅ Sent → BITCOIN = 103599.1
# ✅ Sent → BITCOIN = 103599.0
# ✅ Sent → BITCOIN = 103598.5
# ✅ Sent → BITCOIN = 103608.1
# ✅ Sent → BITCOIN = 103640.6
# ✅ Sent → BITCOIN = 103620.6
# ✅ Sent → BITCOIN = 103614.9
# ✅ Sent → BITCOIN = 103614.0
# ✅ Sent → BITCOIN = 103614.1
# ✅ Sent → BITCOIN = 103617.3
# ✅ Sent → BITCOIN = 103617.4
# ✅ Sent → BITCOIN = 103617.4
# ✅ Sent → BITCOIN = 103607.7
# ✅ Sent → BITCOIN = 103607.7
# ✅ Sent → BITCOIN = 103575.6
# ✅ Sent → BITCOIN = 103549.8
# ✅ Sent → BITCOIN = 103573.2
# ✅ Sent → BITCOIN = 103568.4
# ✅ Sent → BITCOIN = 103554.5
# ✅ Sent → BITCOIN = 103549.9
# ✅ Sent → BITCOIN = 103549.9
# ✅ Sent → BITCOIN = 103554.3
# ✅ Sent → BITCOIN = 103561.8
# ✅ Sent → BITCOIN = 103561.8
# ✅ Sent → BITCOIN = 103575.2
# ✅ Sent → BITCOIN = 103566.0
# ✅ Sent → BITCOIN = 103566.0
# ✅ Sent → BITCOIN = 103580.9
# ✅ Sent → BITCOIN = 103581.4
# ✅ Sent → BITCOIN = 103564.1
# ✅ Sent → BITCOIN = 103564.2
# ✅ Sent → BITCOIN = 103564.2
# ✅ Sent → BITCOIN = 103564.1
# ✅ Sent → BITCOIN = 103564.2
# ✅ Sent → BITCOIN = 103573.3
# ✅ Sent → BITCOIN = 103582.8
# ✅ Sent → BITCOIN = 103590.6
# ✅ Sent → BITCOIN = 103600.3
# ✅ Sent → BITCOIN = 103622.1
# ✅ Sent → BITCOIN = 103622.1
# ✅ Sent → BITCOIN = 103618.4
# ✅ Sent → BITCOIN = 103618.5
# ✅ Sent → BITCOIN = 103622.1
# ✅ Sent → BITCOIN = 103622.1
# ✅ Sent → BITCOIN = 103629.8
